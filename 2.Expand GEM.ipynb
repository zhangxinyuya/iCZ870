# %% [markdown]
# # 从gene中提取信息

# %%
import re
import pandas as pd

# 读取FASTA文件并解析信息
def read_fasta(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

    # 创建正则表达式：分别匹配gene名、locus_tag、EC_number、GO_function、product和protein_id
    gene_name_pattern = re.compile(r'/gene="([^"]+)"')  # 匹配gene名
    locus_tag_pattern = re.compile(r'/locus_tag="([^"]+)"')
    ec_number_pattern = re.compile(r'/EC_number="([^"]+)"')
    go_function_pattern = re.compile(r'/GO_function="([^"]+)"')
    product_pattern = re.compile(r'/product="([^"]+)"')
    protein_id_pattern = re.compile(r'/protein_id="([^"]+)"')

    genes_data = []

    # 按 "gene" 分割文件内容
    genbank_sections = content.split("gene            ")

    # 遍历每个分割后的基因信息
    for section in genbank_sections: 
        locus_tag_match = locus_tag_pattern.search(section)
        if locus_tag_match:
            gene_name = gene_name_pattern.search(section)
            locus_tag = locus_tag_pattern.search(section)
            ec_number = ec_number_pattern.search(section)
            go_function = go_function_pattern.findall(section)
            product = product_pattern.search(section)
            protein_id = protein_id_pattern.search(section)
                # 将提取的信息添加到字典中
            gene_data = {
                'Gene_name': gene_name.group(1) if gene_name else '',
                'Locus_tag': locus_tag.group(1) if locus_tag else '',
                'EC_number': ec_number.group(1) if ec_number else '',
                'GO_function': ', '.join(go_function) if go_function else '',
                'Product': product.group(1) if product else '',
                'Protein_id': protein_id.group(1) if protein_id else ''
            }
                
            genes_data.append(gene_data)

    return genes_data

# 读取FASTA文件路径
file_path = '1.Replace genes in cg14067_rxn/genomic.gbff'  # 替换为你的FASTA文件路径

# 提取基因数据
genes_data = read_fasta(file_path)

# 如果没有数据，打印错误提示
if not genes_data:
    print("未找到符合要求的基因信息，请检查文件格式或内容。")
else:
    # 将数据转换为DataFrame
    df = pd.DataFrame(genes_data)

    # 将结果保存到Excel文件
    output_file = '2.Expand GEM/14067gene.xlsx'
    df.to_excel(output_file, index=False)

    print(f"数据已成功提取并保存到 {output_file}")

# %% [markdown]
# # 从coryneRgeNet7 中爬取与13032的同源信息

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.edge.options import Options

# 初始化Edge WebDriver
options = Options()
options.add_argument("--headless")  # 如果你不希望打开浏览器窗口，取消注释此行
driver = webdriver.Edge(options=options)

# 读取xlsx文件，提取locusTag列
xlsx_file = '2.Expand GEM/14067gene.xlsx'  # 替换为你的文件路径
df = pd.read_excel(xlsx_file)

# 创建一个新列来存储爬取的内容
df['Predicted Genes'] = None

# 逐行遍历xlsx文件的locusTag进行爬取
for index, row in df.iterrows():
    if row['Predicted Genes'] is None:
        locusTag = row['locus_tag']  # 假设locusTag列的名字是'locusTag'
        
        # 打开目标网页
        url = f"https://exbio.wzw.tum.de/coryneregnet/geneInfo.htm?locusTag={locusTag}&type=predicted"
        driver.get(url)
        time.sleep(2)  # 等待页面加载
        
        # 点击指定的按钮
        try:
            button = driver.find_element(By.XPATH, '/html/body/div[2]/ul/li[3]/a')  # 点击目标按钮
            button.click()
            time.sleep(2)  # 等待新页面加载
        except Exception as e:
            print(f"Error clicking button for locusTag {locusTag}: {e}")
            continue  # 如果找不到按钮，跳过当前循环
    
        # 定位到输入框并输入13032进行搜索
        try:
            input_box = driver.find_element(By.XPATH, '//*[@id="homologous-table_filter"]/label/input')
            input_box.clear()
            input_box.send_keys('13032')
            input_box.send_keys(Keys.RETURN)  # 模拟回车
            time.sleep(2)  # 等待搜索结果加载
            
            # 获取搜索结果的链接
            result = driver.find_element(By.XPATH, '//*[@id="homologous-table"]/tbody/tr/td[1]/span/a')
            gene_link = result.get_attribute('href')
            print(gene_link)
            df.at[index, 'Predicted Genes'] = gene_link
        except Exception as e:
            df.at[index, 'Predicted Genes'] = None
            print(f"Error for locusTag {locusTag}: {e}")

# 关闭浏览器
driver.quit()

# 保存结果到新的xlsx文件
output_file = '2.Expand GEM/14067map13032.xlsx'  # 替换为你希望保存的文件路径
df.to_excel(output_file, index=False)

print(f"爬取完成，结果已保存到 {output_file}")

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.edge.options import Options

# 初始化Edge WebDriver
options = Options()
options.add_argument("--headless")  # 如果你不希望打开浏览器窗口，取消注释此行
driver = webdriver.Edge(options=options)

# 读取xlsx文件，提取locusTag列
xlsx_file = '14067map13032_1.xlsx'  # 替换为你的文件路径
df = pd.read_excel(xlsx_file)

# 找到Predicted Genes列为空的行
empty_predicted_genes = df[df['Predicted Genes'].isna()]

# 逐行遍历Predicted Genes列为空的行
for index, row in empty_predicted_genes.iterrows():
    locusTag = row['locus_tag']  # 假设locusTag列的名字是'locusTag'
    
    # 打开目标网页
    url = f"https://exbio.wzw.tum.de/coryneregnet/geneInfo.htm?locusTag={locusTag}&type=predicted"
    driver.get(url)
    time.sleep(2)  # 等待页面加载
    
    # 点击指定的按钮
    try:
        button = driver.find_element(By.XPATH, '/html/body/div[2]/ul/li[3]/a')  # 点击目标按钮
        button.click()
        time.sleep(2)  # 等待新页面加载
    except Exception as e:
        print(f"Error clicking button for locusTag {locusTag}: {e}")
        continue  # 如果找不到按钮，跳过当前循环

    # 定位到输入框并输入13032进行搜索
    try:
        input_box = driver.find_element(By.XPATH, '//*[@id="homologous-table_filter"]/label/input')
        input_box.clear()
        input_box.send_keys('13032')
        input_box.send_keys(Keys.RETURN)  # 模拟回车
        time.sleep(2)  # 等待搜索结果加载
        
        # 获取搜索结果的链接
        result = driver.find_element(By.XPATH, '//*[@id="homologous-table"]/tbody/tr/td[1]/span/a')
        gene_link = result.get_attribute('href')
        print(gene_link)
        df.at[index, 'Predicted Genes'] = gene_link  # 更新 Predicted Genes 列
    except Exception as e:
        df.at[index, 'Predicted Genes'] = None
        print(f"Error for locusTag {locusTag}: {e}")

# 关闭浏览器
driver.quit()

# 保存结果到新的xlsx文件
output_file = '2.Expand GEM/14067map13032.xlsx'  # 替换为你希望保存的文件路径
df.to_excel(output_file, index=False)

print(f"爬取完成，结果已保存到 {output_file}")

# %% [markdown]
# 手动处理不明确的EC号

# %% [markdown]
# # 从KEGG获取有关cg的ec信息

# %%
import pandas as pd
import time
# 设置请求的重试机制
def create_session():
    session = requests.Session()
    retry = Retry(
        total=3,  # 设置最多重试次数
        backoff_factor=1,  # 设置退避因子，重试间隔会指数增长
        status_forcelist=[500, 502, 503, 504]  # 针对这些HTTP错误进行重试
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('https://', adapter)
    session.mount('http://', adapter)
    return session

# 获取基因详细信息
def get_gene_info(gene_id, session):
    # 构建KEGG API的URL，使用get操作获取基因详细信息
    url = f"https://rest.kegg.jp/get/cgb:{gene_id}"
    # 发送GET请求
    response = session.get(url)
    # 检查响应状态码
    if response.status_code == 200:
        # 获取响应文本
        text = response.text
        # 按行分割文本，并取前50行
        lines = text.splitlines()
        # 只返回前50行数据
        return "\n".join(lines[:50])
    else:
        return "Failed to retrieve gene information."

# 提取EC号
def getEC(gene_info):
    ec_pattern = re.compile(r'\[EC:([^\]]+)\]')
    matches = ec_pattern.findall(gene_info)
    return matches

# 读取Excel文件
df = pd.read_excel('14067map13032.xlsx')
# 创建一个会话对象
session = create_session()

# 遍历基因列，查询KEGG并添加EC号
for index, row in df.iterrows():
    gene = row['Predicted Genes']
    ec_number = row['EC_number']
    print(gene, ec_number)  # 获取现有的EC号
    if pd.notnull(gene) and pd.isnull(ec_number):
        gene_info = get_gene_info(gene, session)  # 修正为调用 get_gene_info
        if gene_info != "Failed to retrieve gene information.":
            time.sleep(2)  # 控制请求间隔为2秒，避免过于频繁
            new_ec_number = getEC(gene_info)
            if new_ec_number:
                df.at[index, 'EC_number'] = ', '.join(new_ec_number)
                print(f"替换: {gene} -> {new_ec_number}")
            else:
                print(f"{gene} 没有找到EC号")
        else:
            print(f"{gene} 查询失败或没有结果")

# 保存修改后的Excel文件
df.to_excel('14067map13032_NU.xlsx', index=False)

print('EC号已成功添加并保存到 14067map13032_NU.xlsx')
# Out:
# cg0001 nan
# cg0001 没有找到EC号
# cg0004 2.7.7.7
# cg0005 nan
# cg0005 没有找到EC号
# cg0006 nan
# cg0006 没有找到EC号
# cg0007 5.6.2.2
# cg0008 nan
# cg0008 没有找到EC号
# cg0009 nan
# cg0009 没有找到EC号
# cg0010 nan
# cg0010 没有找到EC号
# cg0012 nan
# cg0012 没有找到EC号
# cg0013 nan
# cg0013 没有找到EC号
# cg0014 nan
# cg0014 没有找到EC号
# cg0015 5.6.2.2
# cg0016 nan
# cg0016 没有找到EC号
# nan nan
# nan nan
# cg0018 nan
# cg0018 没有找到EC号
# cg0019 nan
# cg0019 没有找到EC号
# cg0021 nan
# cg0021 没有找到EC号
# cg0025 nan
# cg0025 没有找到EC号
# cg0026 nan
# cg0026 没有找到EC号
# cg0027 nan
# cg0027 没有找到EC号
# cg0029 nan
# cg0029 没有找到EC号
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# nan nan
# cg0419 nan
# cg0419 没有找到EC号
# nan nan
# nan nan
# nan nan
# nan nan
# cg0038 nan
# 替换: cg0038 -> ['1.11.1.28']
# cg0040 nan
# cg0040 没有找到EC号
# cg0041 nan
# cg0041 没有找到EC号
# cg0042 nan
# cg0042 没有找到EC号
# cg0043 nan
# cg0043 没有找到EC号
# cg0044 nan
# cg0044 没有找到EC号
# cg0045 nan
# cg0045 没有找到EC号
# nan nan
# nan nan
# cg3404 nan
# cg3404 没有找到EC号
# cg3405 nan
# cg3405 没有找到EC号
# cg3407 nan
# cg3407 没有找到EC号
# nan nan
# cg3408 nan
# cg3408 没有找到EC号
# cg3409 2.7.1.49
# cg3410 nan
# cg3410 没有找到EC号
# cg3402 nan
# cg3402 没有找到EC号
# cg3403 nan
# cg3403 没有找到EC号
# nan nan
# nan nan
# nan nan
# cg3412 nan
# cg3412 没有找到EC号
# cg3413 nan
# cg3413 没有找到EC号
# cg3414 nan
# cg3414 没有找到EC号
# cg3415 2.7.7.72
# cg3417 nan
# cg3417 没有找到EC号
# cg3418 nan
# cg3418 没有找到EC号
# cg3419 nan
# cg3419 没有找到EC号
# cg3420 nan
# cg3420 没有找到EC号
# cg3422 1.8.1.9
# cg3423 nan
# cg3423 没有找到EC号
# cg3424 nan
# 替换: cg3424 -> ['3.5.1.28']
# cg3425 nan
# cg3425 没有找到EC号
# cg3426 nan
# cg3426 没有找到EC号
# cg3427 nan
# cg3427 没有找到EC号
# cg3428 2.1.1.170
# cg3429 nan
# cg3429 没有找到EC号
# cg3430 nan
# cg3430 没有找到EC号
# cg3431 3.1.26.5
# cg3432 nan
# cg3432 没有找到EC号
# EC号已成功添加并保存到 14067map13032_EC1.xlsx

# %% [markdown]
# # 进一步将CLEAN 和 ECRECer 预测相同的EC号补充进入表格

# %%
import pandas as pd

# 读取TSV文件，假设格式为protein_id号和EC号
tsv_file = '2.Expand GEM/利用CLEAN和ECRECer预测的EC号/SAME_EC.csv'  # 输入你的TSV文件路径
tsv_df = pd.read_csv(tsv_file, sep=',', header=None, names=['Protein_id', 'EC_number'])

# 读取Excel文件，假设有'protein_id'列需要匹配并填充'EC Number'列
excel_file = '2.Expand GEM/14067map13032_EC1.xlsx'  # 输入你的Excel文件路径
df = pd.read_excel(excel_file)

# 清理数据：去除多余的空格并统一大小写
tsv_df['Protein_id'] = tsv_df['Protein_id'].str.strip().str.upper()  # 统一去空格和大小写
df['Protein_id'] = df['Protein_id'].str.strip().str.upper()  # 同样清理Excel中的AST列

# 创建protein_id到EC号的映射字典
ast_to_ec = dict(zip(tsv_df['Protein_id'], tsv_df['EC_number']))
print(ast_to_ec)
# 遍历Excel文件中的'protein_id'列，查找并填充相应的EC号，只对EC号为空的行进行映射
def match_ec(row):
    if pd.isnull(row['EC_number']):  # 仅当EC Number为空时才进行映射
        ast_value = row['Protein_id']
        ec_number = ast_to_ec.get(ast_value, None)  # 如果找不到匹配的EC号，则返回None
        if ec_number:  # 如果找到了EC号，就进行替换
            print(f"替换 protein_id: {ast_value} -> 新的 EC_number: {ec_number}")
        return ec_number
    else:
        return row['EC_number']  # 如果已有EC号，则保持不变

# 将EC号添加到'EC Number'列
df['EC_number'] = df.apply(match_ec, axis=1)

# 保存修改后的Excel文件
output_file = '2.Expand GEM/14067map13032_EC2.xlsx'
df.to_excel(output_file, index=False)

print(f'EC号已成功添加并保存为 {output_file}')
# Out:
667.1': '2.5.1.49', 'WP_034983883.1': '3.4.21.105', 'WP_003861079.1': '2.7.11.1', 'WP_003861085.1': '3.1.3.16', 'WP_003859941.1': '3.5.1.5', 'WP_003859939.1': '3.5.1.5', 'WP_003863695.1': '2.7.1.17', 'WP_003863696.1': '6.3.2.1', 'WP_034983442.1': '1.14.11.33', 'WP_003862466.1': '1.2.1.27', 'WP_003862468.1': '5.3.1.30', 'WP_003857130.1': '3.7.1.22', 'WP_003863409.1': '2.10.1.1', 'WP_034983466.1': '2.6.1.9', 'WP_003863392.1': '3.5.4.33', 'WP_034983471.1': '2.4.2.29', 'WP_003863352.1': '2.7.2.4', 'WP_003855734.1': '1.11.1.6', 'WP_003863326.1': '2.7.13.3', 'WP_003863273.1': '5.4.99.24', 'WP_003863254.1': '2.7.7.24', 'WP_003863250.1': '4.2.1.46', 'WP_003863188.1': '1.1.1.22', 'WP_003863185.1': '1.8.1.4', 'WP_003859738.1': '3.5.1.10', 'WP_170844354.1': '4.1.2.4', 'WP_003855492.1': '1.3.1.98', 'WP_003855505.1': '1.5.1.2', 'WP_003860420.1': '2.5.1.61', 'WP_003860452.1': '4.2.1.24', 'WP_003860460.1': '4.1.1.37', 'WP_170844355.1': '5.4.3.8', 'WP_003860472.1': '2.5.1.74', 'WP_003860475.1': '1.2.1.4', 'WP_003860502.1': '4.1.3.36', 'WP_003860504.1': '4.2.1.96', 'WP_094244210.1': '4.2.1.113', 'WP_003860510.1': '2.2.1.9', 'WP_003860519.1': '2.5.1.29', 'WP_003854195.1': '2.6.1.19', 'WP_003860618.1': '2.7.4.3', 'WP_003860630.1': '5.1.3.2', 'WP_003860639.1': '5.4.99.12', 'WP_003860680.1': '5.1.1.1', 'WP_003860688.1': '2.3.1.234', 'WP_003860690.1': '4.2.1.136', 'WP_003860701.1': '1.1.1.205', 'WP_003860710.1': '6.3.5.2', 'WP_170844357.1': '4.1.99.3', 'WP_003854647.1': '2.1.1.207', 'WP_003860777.1': '2.3.1.31', 'WP_003860782.1': '4.2.1.79', 'WP_003860785.1': '2.3.3.5', 'WP_003863641.1': '6.1.1.2', 'WP_003863636.1': '2.4.2.9', 'WP_00386362 ...
# 替换 protein_id: WP_034983883.1 -> 新的 EC_number: 3.4.21.105
# 替换 protein_id: WP_003863459.1 -> 新的 EC_number: 6.3.2.2
# 替换 protein_id: WP_003863326.1 -> 新的 EC_number: 2.7.13.3
# 替换 protein_id: WP_003860519.1 -> 新的 EC_number: 2.5.1.29
# 替换 protein_id: WP_003863604.1 -> 新的 EC_number: 1.14.14.10
# 替换 protein_id: WP_003863544.1 -> 新的 EC_number: 3.6.4.13
# 替换 protein_id: WP_003858456.1 -> 新的 EC_number: 2.7.7.75
# 替换 protein_id: WP_003858525.1 -> 新的 EC_number: 4.1.3.17
# 替换 protein_id: WP_094244227.1 -> 新的 EC_number: 3.6.4.13
# 替换 protein_id: WP_003860306.1 -> 新的 EC_number: 3.4.21.105
# 替换 protein_id: WP_003853863.1 -> 新的 EC_number: 2.7.13.3
# 替换 protein_id: WP_003862931.1 -> 新的 EC_number: 2.8.1.1
# 替换 protein_id: WP_003862578.1 -> 新的 EC_number: 1.5.1.39
# 替换 protein_id: WP_004567966.1 -> 新的 EC_number: 1.6.99.1
# 替换 protein_id: WP_004567997.1 -> 新的 EC_number: 3.6.1.31
# 替换 protein_id: WP_003860943.1 -> 新的 EC_number: 3.5.1.59
# EC号已成功添加并保存为 14067map13032_EC2.xlsx

# %% [markdown]
# # 根据EC号获取相应的R{5}反应名称

# %%
import pandas as pd
import requests
import re
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry


# 设置请求的重试机制
def create_session():
    session = requests.Session()
    retry = Retry(
        total=3,  # 设置最多重试次数
        backoff_factor=1,  # 设置退避因子，重试间隔会指数增长
        status_forcelist=[500, 502, 503, 504]  # 针对这些HTTP错误进行重试
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('https://', adapter)
    session.mount('http://', adapter)
    return session


def get_rxn_from_ec(ec_number, session):
    try:
        # 构造URL并发送请求
        url = f"https://rest.kegg.jp/get/{ec_number}"
        response = session.get(url)
        time.sleep(5)  # 控制请求频率，避免过于频繁请求被限制

        if response.status_code == 200:
            data = response.text.strip()
            start = data.find("ALL_REAC")
            end = data.find("SUBSTRATE")

            # 提取反应编号
            if start != -1 and end != -1:
                relevant_text = data[start:end].strip()
                rxn_numbers = re.findall(r'R\d+', relevant_text)
                print(f"EC: {ec_number} -> RXNs: {rxn_numbers}")
                return rxn_numbers
            else:
                print(f"No relevant text found for EC number: {ec_number}")
                return None
        else:
            print(f"Failed to retrieve data for EC number: {ec_number}, Status code: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Request failed for EC number: {ec_number}, Error: {e}")
        return None

# 定义安全解析函数，确保只对非空字符串进行解析
def safe_eval(val):
    if isinstance(val, str) and val.strip():  # 确保是非空字符串
        try:
            return eval(val)  # 转换为列表
        except:
            return None  # 如果转换失败返回None
    return None  # 如果不是字符串或为空，返回None

# 读取Excel文件
file_path = '2.Expand GEM/14067map13032_EC2.xlsx'  # 替换为您的文件路径
df = pd.read_excel(file_path)

# 新增一列用于存储RXN号
df['KEGG Rxn number'] = None

# 创建会话对象
session = create_session()

# 使用循环处理每一行
for index, row in df.iterrows():
    ec_number = row['EC_number']
    if pd.notnull(ec_number):
        rxn_numbers = get_rxn_from_ec(ec_number, session)
        df.at[index, 'KEGG Rxn number'] = ', '.join(rxn_numbers) if rxn_numbers else None

# 保存结果到新的Excel文件
output_file_path = '2.Expand GEM/14067map13032_R1.xlsx'  # 输出文件的路径
df.to_excel(output_file_path, index=False)
print(f"Results saved to {output_file_path}")
# Out:
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# No relevant text found for EC number: 5.6.2.2
# No relevant text found for EC number: 5.6.2.2
# EC: 1.11.1.28 -> RXNs: ['R12602', 'R12603']
# Failed to retrieve data for EC number: 7.5.2.-, Status code: 404
# EC: 5.2.1.8 -> RXNs: ['R04273']
# No relevant text found for EC number: 3.4.21.105
# No relevant text found for EC number: 7.2.2.17 7.2.2.-
# EC: 2.7.11.1 -> RXNs: ['R00162', 'R03632']
# EC: 2.7.11.1 -> RXNs: ['R00162', 'R03632']
# EC: 3.1.3.16 -> RXNs: ['R00164']
# EC: 1.2.1.16 1.2.1.79 1.2.1.20 -> RXNs: ['R00713', 'R00714']
# EC: 3.1.2.6 -> RXNs: ['R04090', 'R01736']
# No relevant text found for EC number: 2.7.13.3
# EC: 2.8.1.6 -> RXNs: ['R01078']
# EC: 3.5.4.1 3.5.4.21 -> RXNs: ['R00974', 'R01411']
# EC: 2.3.1.286 -> RXNs: ['R10634', 'R10633']
# EC: 3.1.1.3 -> RXNs: ['R01369', 'R02250', 'R02687', 'R02688', 'R05209']
# EC: 3.1.1.3 -> RXNs: ['R01369', 'R02250', 'R02687', 'R02688', 'R05209']
# EC: 3.5.1.5 -> RXNs: ['R00131', 'R06134']
# EC: 3.5.1.5 -> RXNs: ['R00131', 'R06134']
# EC: 3.5.1.5 -> RXNs: ['R00131', 'R06134']
# EC: 3.2.2.4 -> RXNs: ['R00182']
# EC: 1.5.5.2 1.2.1.88 -> RXNs: ['R01253']
# Failed to retrieve data for EC number: 3.1.3.-, Status code: 404
# EC: 1.1.1.67 -> RXNs: ['R00868']
# EC: 2.7.1.17 -> RXNs: ['R01639']
# EC: 6.3.2.1 -> RXNs: ['R02473']
# EC: 2.1.2.11 -> RXNs: ['R01226', 'R01216']
# No relevant text found for EC number: 3.2.2.21
# EC: 4.1.1.11 -> RXNs: ['R00489']
# No relevant text found for EC number: 5.6.2.6
# EC: 2.3.1.79 -> RXNs: ['R01556', 'R06251']
# No relevant text found for EC number: 1.14.11.33
# No relevant text found for EC number: 3.2.2.20
# EC: 3.5.99.10 -> RXNs: ['R11098', 'R11099']
# Failed to retrieve data for EC number: 3.4.24.-, Status code: 404
# Failed to retrieve data for EC number: 3.4.-.-, Status code: 404
# EC: 2.7.1.92 -> RXNs: ['R05661']
# EC: 1.2.1.18 1.2.1.27 -> RXNs: ['R00705', 'R00706']
# EC: 5.3.1.30 -> RXNs: ['R08503']
# EC: 3.7.1.22 -> RXNs: ['R08603']
# EC: 4.2.1.44 -> RXNs: ['R02782']
# EC: 1.1.1.18 1.1.1.369 -> RXNs: ['R01183']
# EC: 1.4.1.13 -> RXNs: ['R00114', 'R00248', 'R00256']
# EC: 1.4.1.13 -> RXNs: ['R00114', 'R00248', 'R00256']
# EC: 6.3.2.2 -> RXNs: ['R00894', 'R10993']
# Failed to retrieve data for EC number: 2.4.2.-, Status code: 404
# No relevant text found for EC number: 2.4.2.46
# EC: 1.1.1.333 -> RXNs: ['R10113']
# EC: 1.1.98.3 -> RXNs: ['R10112']
# EC: 2.4.1.287 -> RXNs: ['R12078', 'R12079']
# No relevant text found for EC number: 7.5.2.14
# EC: 2.7.7.80 2.7.7.- 2.8.1.11 2.8.1.- -> RXNs: ['R07459']
# EC: 2.8.1.12 -> RXNs: ['R09395']
# EC: 4.6.1.17 -> RXNs: ['R11372']
# EC: 2.10.1.1 -> RXNs: ['R09735']
# Failed to retrieve data for EC number: 7.5.2.-, Status code: 404
# EC: 2.6.1.9 -> RXNs: ['R03243', 'R00694', 'R00734']
# EC: 1.3.1.12 -> RXNs: ['R01728']
# EC: 3.5.4.33 -> RXNs: ['R10223']
# EC: 2.4.2.29 -> RXNs: ['R10209']
# EC: 6.1.1.17 -> RXNs: ['R05578']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 6.3.5.13 -> RXNs: ['R00256', 'R05030', 'R12330', 'R12331']
# EC: 6.3.5.13 -> RXNs: ['R00256', 'R05030', 'R12330', 'R12331']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 2.3.3.13 -> RXNs: ['R01213']
# EC: 2.7.2.4 -> RXNs: ['R00480']
# EC: 1.2.1.11 -> RXNs: ['R02291']
# EC: 1.11.1.6 -> RXNs: ['R00009', 'R00602', 'R02670']
# No relevant text found for EC number: 2.8.4.2
# No relevant text found for EC number: 2.7.13.3
# EC: 1.3.8.6 -> RXNs: ['R02488', 'R02487', 'R03028', 'R10074']
# No relevant text found for EC number: 3.2.2.- 4.2.99.18
# EC: 3.6.1.55 -> RXNs: ['R09832']
# No relevant text found for EC number: 7.4.2.8
# No relevant text found for EC number: 5.6.2.1
# EC: 4.6.1.1 -> RXNs: ['R00089', 'R00434']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# No relevant text found for EC number: 5.4.99.24
# EC: 1.1.1.306 -> RXNs: ['R09129', 'R10301']
# EC: 4.2.1.47 -> RXNs: ['R00888']
# EC: 3.1.3.5 -> RXNs: ['R07297', 'R00183', 'R00511', 'R00963', 'R01126', 'R01227', 'R02323', 'R02719', 'R03346', 'R01569', 'R01664', 'R01968', 'R02088', 'R02102', 'R12958']
# EC: 3.5.2.10 -> RXNs: ['R01884']
# EC: 2.7.7.24 -> RXNs: ['R02328']
# EC: 5.1.3.13 1.1.1.133 -> RXNs: ['R06514']
# EC: 4.2.1.46 -> RXNs: ['R06513']
# No relevant text found for EC number: 3.4.21.26
# EC: 5.1.3.14 -> RXNs: ['R00420', 'R00414', 'R02707']
# EC: 1.1.1.336 -> RXNs: ['R03317']
# EC: 1.1.1.22 -> RXNs: ['R00286']
# EC: 1.8.1.4 -> RXNs: ['R08550', 'R03815', 'R07618', 'R01698']
# EC: 2.7.7.9 -> RXNs: ['R00289']
# Failed to retrieve data for EC number: 3.1.1.-, Status code: 404
# EC: 1.3.5.1 -> RXNs: ['R02164', 'R13223']
# EC: 1.3.5.1 -> RXNs: ['R02164', 'R13223']
# EC: 3.5.1.10 -> RXNs: ['R00944']
# EC: 4.1.2.4 -> RXNs: ['R01066']
# No relevant text found for EC number: 7.2.2.8
# No relevant text found for EC number: 7.6.2.5
# EC: 1.3.1.98 -> RXNs: ['R03192', 'R03191']
# EC: 6.2.1.3 -> RXNs: ['R00390', 'R01280']
# EC: 2.4.1.250 -> RXNs: ['R09634']
# EC: 5.4.2.11 -> RXNs: ['R01516', 'R01518']
# No relevant text found for EC number: 2.7.13.3
# EC: 3.6.1.11 3.6.1.40 -> RXNs: ['R03042', 'R03409']
# EC: 1.5.1.2 -> RXNs: ['R01248', 'R01251', 'R03291', 'R03293']
# EC: 1.2.1.70 -> RXNs: ['R04109']
# EC: 2.5.1.61 -> RXNs: ['R00084']
# EC: 4.2.1.118 -> RXNs: ['R01627']
# EC: 4.2.1.10 -> RXNs: ['R03084']
# EC: 1.1.1.24 -> RXNs: ['R01872', 'R06847']
# No relevant text found for EC number: 7.2.2.7
# EC: 4.2.1.75 -> RXNs: ['R03165']
# EC: 4.2.1.24 -> RXNs: ['R00036']
# EC: 4.1.1.37 -> RXNs: ['R03197', 'R04972']
# EC: 1.3.3.4 -> RXNs: ['R03222']
# EC: 5.4.3.8 -> RXNs: ['R02272']
# EC: 2.5.1.74 -> RXNs: ['R10757']
# EC: 6.2.1.26 -> RXNs: ['R04030']
# EC: 1.2.1.26 -> RXNs: ['R00264']
# EC: 4.2.1.41 -> RXNs: ['R02279']
# EC: 3.1.2.29 -> RXNs: ['R09643']
# EC: 4.1.3.36 -> RXNs: ['R04150', 'R07263']
# EC: 4.2.1.96 -> RXNs: ['R04734']
# No relevant text found for EC number: 3.4.13.21
# EC: 4.2.1.113 -> RXNs: ['R04031']
# EC: 2.2.1.9 -> RXNs: ['R08165']
# Failed to retrieve data for EC number: 2.4.1.-, Status code: 404
# EC: 2.1.1.163 -> RXNs: ['R09736']
# EC: 1.3.99.38 -> RXNs: ['R11654']
# EC: 2.5.1.29 -> RXNs: ['R02061']
# EC: 2.6.1.19 -> RXNs: ['R01648', 'R00908']
# EC: 1.2.1.16 1.2.1.79 1.2.1.20 -> RXNs: ['R00713', 'R00714']
# EC: 2.7.7.6 -> RXNs: ['R00444', 'R00435', 'R00441', 'R00442', 'R00443', 'R10813']
# EC: 2.7.7.6 -> RXNs: ['R00444', 'R00435', 'R00441', 'R00442', 'R00443', 'R10813']
# No relevant text found for EC number: 7.2.2.17 7.2.2.-
# Failed to retrieve data for EC number: 7.-.-.-, Status code: 404
# EC: 1.2.1.18 1.2.1.27 -> RXNs: ['R00705', 'R00706']
# EC: 1.2.1.3 -> RXNs: ['R00538', 'R00631', 'R00710', 'R00904', 'R01752', 'R02549', 'R02678', 'R02940', 'R03283', 'R03869', 'R04065', 'R04506', 'R04903', 'R05050', 'R05286', 'R06366', 'R08146', 'R00264', 'R01986', 'R02957', 'R05237', 'R05238']
# EC: 1.18.1.3 -> RXNs: ['R05875', 'R02000']
# EC: 2.7.9.2 -> RXNs: ['R00199']
# EC: 2.7.9.2 -> RXNs: ['R00199']
# EC: 2.7.4.3 -> RXNs: ['R00127', 'R01547', 'R11319']
# No relevant text found for EC number: 3.4.11.18
# EC: 5.1.3.2 -> RXNs: ['R00291', 'R00418', 'R02984']
# EC: 2.7.7.6 -> RXNs: ['R00444', 'R00435', 'R00441', 'R00442', 'R00443', 'R10813']
# EC: 5.4.99.12 -> RXNs: ['R03020']
# EC: 2.1.1.79 -> RXNs: ['R03411']
# Failed to retrieve data for EC number: 3.4.21.-, Status code: 404
# EC: 5.4.2.10 -> RXNs: ['R02060']
# EC: 5.1.1.1 -> RXNs: ['R00401']
# EC: 2.3.1.234 -> RXNs: ['R10648']
# EC: 2.3.1.266 -> RXNs: ['R04316']
# EC: 2.3.1.234 -> RXNs: ['R10648']
# EC: 4.2.1.136 5.1.99.6 -> RXNs: ['R10267', 'R10268']
# No relevant text found for EC number: 5.6.1.7
# EC: 1.1.1.205 -> RXNs: ['R01130', 'R08240']
# EC: 1.1.1.205 -> RXNs: ['R01130', 'R08240']
# EC: 6.3.5.2 -> RXNs: ['R00256', 'R01230', 'R01231', 'R08244']
# EC: 2.5.1.149 -> RXNs: ['R12283', 'R12284']
# EC: 2.5.1.1 2.5.1.10 2.5.1.29 -> RXNs: ['R01658']
# EC: 4.1.99.3 -> RXNs: ['R00034', 'R08765']
# No relevant text found for EC number: 7.4.2.11
# No relevant text found for EC number: 7.4.2.11
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 2.3.1.286 2.3.1.313 -> RXNs: ['R10634', 'R10633']
# EC: 3.5.4.33 -> RXNs: ['R10223']
# No relevant text found for EC number: 2.1.1.207
# EC: 1.5.1.5 3.5.4.9 -> RXNs: ['R01220']
# EC: 2.3.1.31 -> RXNs: ['R01776']
# EC: 2.5.1.47 -> RXNs: ['R00897', 'R03601', 'R04859', 'R07274']
# EC: 4.2.1.3 -> RXNs: ['R01324', 'R01325', 'R01900']
# EC: 4.1.3.30 -> RXNs: ['R00409']
# EC: 2.3.3.16 -> RXNs: ['R00351']
# EC: 1.1.1.42 -> RXNs: ['R00267', 'R00268', 'R01899']
# No relevant text found for EC number: 7.2.2.17 7.2.2.-
# No relevant text found for EC number: 3.1.11.2
# No relevant text found for EC number: 7.6.2.8
# EC: 6.1.1.2 -> RXNs: ['R03664']
# No relevant text found for EC number: 3.4.16.4
# EC: 2.4.2.9 -> RXNs: ['R00966']
# EC: 5.4.2.8 -> RXNs: ['R01818']
# EC: 1.6.5.2 -> RXNs: ['R07358', 'R02964', 'R03643', 'R03816', 'R07359']
# EC: 6.4.1.1 -> RXNs: ['R00344']
# EC: 1.8.1.9 -> RXNs: ['R02016', 'R00900', 'R03596', 'R09372']
# EC: 4.2.1.3 -> RXNs: ['R01324', 'R01325', 'R01900']
# EC: 4.1.3.30 -> RXNs: ['R00409']
# EC: 2.3.3.16 -> RXNs: ['R00351']
# EC: 6.4.1.2 6.4.1.3 6.4.1.- 6.3.4.14 -> RXNs: ['R00742']
# EC: 2.8.1.1 2.8.1.2 -> RXNs: ['R01931']
# Failed to retrieve data for EC number: 3.6.1.-, Status code: 404
# EC: 6.4.1.3 6.4.1.- 2.1.3.15 -> RXNs: ['R01859', 'R08924']
# EC: 6.4.1.3 6.4.1.- 2.1.3.15 -> RXNs: ['R01859', 'R08924']
# EC: 6.3.4.15 -> RXNs: ['R04562', 'R01074', 'R05145']
# EC: 6.3.4.18 -> RXNs: ['R07404']
# EC: 4.1.1.21 -> RXNs: ['R04209']
# EC: 1.14.14.10 -> RXNs: ['R09798']
# EC: 1.1.1.100 -> RXNs: ['R02767', 'R04533', 'R04534', 'R04536', 'R04543', 'R04566', 'R04953', 'R04964', 'R07763', 'R10116', 'R10120']
# Failed to retrieve data for EC number: 7.5.2.-, Status code: 404
# EC: 2.4.1.289 -> RXNs: ['R10175', 'R12077']
# EC: 2.7.7.13 -> RXNs: ['R00885']
# EC: 5.4.2.8 -> RXNs: ['R01818']
# EC: 5.3.1.8 -> RXNs: ['R00772', 'R01819']
# EC: 3.13.2.1 -> RXNs: ['R00192']
# EC: 2.7.4.9 -> RXNs: ['R02094', 'R02098']
# No relevant text found for EC number: 2.7.13.3
# No relevant text found for EC number: 7.4.2.8
# EC: 3.6.1.- 3.1.3.100 -> RXNs: ['R02135']
# EC: 2.5.1.19 -> RXNs: ['R03460']
# No relevant text found for EC number: 3.6.4.13
# No relevant text found for EC number: 5.6.2.4
# EC: 3.6.1.22 -> RXNs: ['R00103', 'R11104', 'R03004']
# No relevant text found for EC number: 5.6.2.4
# EC: 4.3.3.6 -> RXNs: ['R00256', 'R10088', 'R10089', 'R07456']
# EC: 3.5.1.2 -> RXNs: ['R00256', 'R01579', 'R06134']
# EC: 3.1.3.15 -> RXNs: ['R03013']
# Failed to retrieve data for EC number: 7.2.2.-, Status code: 404
# EC: 2.6.1.17 -> RXNs: ['R04475']
# No relevant text found for EC number: 5.6.2.4
# EC: 2.3.2.5 -> RXNs: ['R04058']
# EC: 2.6.1.52 -> RXNs: ['R04173', 'R05085']
# EC: 2.3.3.16 -> RXNs: ['R00351']
# EC: 5.2.1.8 -> RXNs: ['R04273']
# Failed to retrieve data for EC number: 6.4.1.-, Status code: 404
# Failed to retrieve data for EC number: 2.3.1.-, Status code: 404
# EC: 2.3.1.31 2.3.1.46 -> RXNs: ['R01776']
# No relevant text found for EC number: 1.20.4.3
# EC: 1.5.1.3 -> RXNs: ['R00939', 'R00936', 'R00937', 'R00940', 'R02235', 'R02236', 'R11765']
# EC: 2.1.1.45 -> RXNs: ['R02101']
# EC: 3.1.3.7 -> RXNs: ['R00188', 'R00508']
# No relevant text found for EC number: 5.6.2.6 5.6.2.4
# No relevant text found for EC number: 3.2.2.- 4.2.99.18
# EC: 5.3.1.9 -> RXNs: ['R02740', 'R00771', 'R02739', 'R03321', 'R13199']
# EC: 5.4.99.5 -> RXNs: ['R01715']
# No relevant text found for EC number: 3.6.4.12
# EC: 2.1.2.2 -> RXNs: ['R04325', 'R04326']
# EC: 2.1.2.3 -> RXNs: ['R04560']
# EC: 4.1.3.34 -> RXNs: ['R00354']
# No relevant text found for EC number: 2.7.13.3
# Failed to retrieve data for EC number: 3.4.21.-, Status code: 404
# EC: 2.7.7.75 -> RXNs: ['R09726']
# EC: 6.3.3.2 -> RXNs: ['R02301']
# EC: 2.7.7.9 -> RXNs: ['R00289']
# EC: 2.10.1.1 -> RXNs: ['R09735']
# EC: 2.4.1.109 -> RXNs: ['R04072', 'R07620', 'R11399']
# No relevant text found for EC number: 2.1.1.198
# EC: 6.1.1.10 -> RXNs: ['R03659', 'R04773']
# No relevant text found for EC number: 3.6.4.12
# EC: 1.1.1.28 -> RXNs: ['R00704']
# EC: 2.1.1.72 -> RXNs: ['R02961']
# Failed to retrieve data for EC number: 3.1.21.-, Status code: 404
# EC: 2.1.1.182 -> RXNs: ['R10716']
# EC: 2.7.1.148 -> RXNs: ['R05634']
# EC: 2.7.1.35 -> RXNs: ['R00174', 'R01909', 'R02493']
# EC: 2.7.4.1 -> RXNs: ['R02184']
# EC: 4.1.3.17 -> RXNs: ['R00008', 'R00350']
# EC: 3.1.1.29 -> RXNs: ['R04238']
# EC: 1.13.12.16 -> RXNs: ['R00025']
# EC: 1.2.1.12 -> RXNs: ['R01061']
# EC: 3.1.1.29 -> RXNs: ['R04238']
# EC: 2.7.6.1 -> RXNs: ['R01049']
# EC: 2.7.7.23 -> RXNs: ['R00416']
# No relevant text found for EC number: 2.7.13.3
# EC: 2.3.2.2 -> RXNs: ['R04159', 'R01262', 'R01687', 'R03867', 'R04935', 'R03916', 'R03970', 'R03971']
# No relevant text found for EC number: 5.6.2.4
# EC: 4.2.1.11 -> RXNs: ['R00658', 'R04206']
# EC: 3.6.1.11 3.6.1.40 -> RXNs: ['R03042', 'R03409']
# EC: 3.5.1.115 -> RXNs: ['R10617']
# EC: 2.5.1.54 -> RXNs: ['R01826']
# EC: 2.5.1.68 -> RXNs: ['R08528']
# EC: 2.7.1.33 -> RXNs: ['R03018', 'R02971', 'R04391']
# EC: 2.1.2.1 -> RXNs: ['R00945', 'R09099']
# EC: 2.6.1.85 -> RXNs: ['R00256', 'R01716', 'R05552']
# EC: 3.5.2.9 -> RXNs: ['R00251']
# EC: 4.2.1.2 -> RXNs: ['R01082']
# No relevant text found for EC number: 1.14.14.28
# EC: 1.14.14.5 1.14.14.34 -> RXNs: ['R07210', 'R10206']
# EC: 3.1.3.11 -> RXNs: ['R00762', 'R04780', 'R01845']
# No relevant text found for EC number: 3.1.11.6
# No relevant text found for EC number: 3.1.11.6
# EC: 1.17.7.4 -> RXNs: ['R05884', 'R08210']
# EC: 4.1.1.44 -> RXNs: ['R03470']
# EC: 6.6.1.1 -> RXNs: ['R03877']
# EC: 2.8.1.7 -> RXNs: ['R07460', 'R11528', 'R11529']
# EC: 2.4.2.19 -> RXNs: ['R03348']
# EC: 2.5.1.72 -> RXNs: ['R04292']
# EC: 6.3.1.20 -> RXNs: ['R11143', 'R12433', 'R12449', 'R07770', 'R07771', 'R12429']
# EC: 1.14.13.2 -> RXNs: ['R01298']
# Failed to retrieve data for EC number: 7.-.-.-, Status code: 404
# EC: 1.11.1.24 -> RXNs: ['R12570']
# EC: 1.1.1.169 -> RXNs: ['R02472']
# EC: 1.20.4.1 -> RXNs: ['R05747']
# EC: 3.5.1.103 -> RXNs: ['R09651']
# EC: 2.6.1.17 -> RXNs: ['R04475']
# EC: 2.3.1.117 -> RXNs: ['R04365']
# EC: 2.3.1.117 -> RXNs: ['R04365']
# EC: 3.5.1.18 -> RXNs: ['R02734']
# EC: 2.5.1.15 -> RXNs: ['R03067', 'R03066']
# EC: 2.4.1.266 -> RXNs: ['R09663']
# EC: 2.1.1.187 -> RXNs: ['R07233']
# No relevant text found for EC number: 3.2.1.26
# EC: 2.4.1.21 -> RXNs: ['R02421', 'R06049']
# EC: 2.7.7.27 -> RXNs: ['R00948']
# EC: 4.1.1.71 -> RXNs: ['R00272']
# Failed to retrieve data for EC number: 3.1.1.-, Status code: 404
# EC: 2.1.1.14 -> RXNs: ['R04405', 'R09365']
# EC: 1.14.13.148 -> RXNs: ['R05623']
# EC: 7.1.1.7 -> RXNs: ['R11325', 'R11885', 'R11886']
# EC: 7.1.1.7 -> RXNs: ['R11325', 'R11885', 'R11886']
# EC: 2.1.1.37 -> RXNs: ['R00380', 'R04858']
# No relevant text found for EC number: 5.6.2.7
# EC: 6.1.1.19 -> RXNs: ['R03646']
# EC: 4.1.1.20 -> RXNs: ['R00451']
# EC: 1.1.1.3 -> RXNs: ['R01773', 'R01775']
# EC: 2.7.1.39 -> RXNs: ['R01771']
# EC: 1.7.5.1 1.7.99.- -> RXNs: ['R09497']
# EC: 1.7.5.1 1.7.99.- -> RXNs: ['R09497']
# EC: 1.7.5.1 1.7.99.- -> RXNs: ['R09497']
# EC: 2.7.7.77 -> RXNs: ['R11581']
# EC: 2.10.1.1 -> RXNs: ['R09735']
# EC: 4.1.99.22 -> RXNs: ['R09394']
# EC: 2.1.1.297 -> RXNs: ['R10806']
# EC: 2.7.7.87 -> RXNs: ['R10463']
# EC: 2.7.8.33 2.7.8.35 -> RXNs: ['R08856', 'R12859']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# EC: 7.1.2.2 -> RXNs: ['R00086']
# Failed to retrieve data for EC number: 3.1.-.-, Status code: 404
# EC: 5.1.99.1 -> RXNs: ['R02765', 'R09979']
# EC: 1.14.14.5 1.14.14.34 -> RXNs: ['R07210', 'R10206']
# No relevant text found for EC number: 7.6.2.14
# No relevant text found for EC number: 2.4.1.18
# EC: 2.4.99.16 -> RXNs: ['R09994']
# Failed to retrieve data for EC number: 7.2.2.-, Status code: 404
# EC: 2.8.1.7 -> RXNs: ['R07460', 'R11528', 'R11529']
# EC: 2.7.11.1 -> RXNs: ['R00162', 'R03632']
# Failed to retrieve data for EC number: 2.3.1.-, Status code: 404
# EC: 2.8.1.13 -> RXNs: ['R08700']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 6.5.1.2 -> RXNs: ['R00382']
# EC: 6.3.5.6 6.3.5.7 -> RXNs: ['R04212']
# EC: 6.3.5.6 6.3.5.7 -> RXNs: ['R04212']
# EC: 2.7.1.11 2.7.1.90 -> RXNs: ['R04779', 'R00756', 'R00767', 'R00769', 'R00770', 'R01843', 'R03236', 'R03237', 'R03238', 'R03239']
# EC: 5.4.99.62 -> RXNs: ['R08247']
# EC: 6.3.5.6 6.3.5.7 -> RXNs: ['R04212']
# EC: 1.5.1.40 -> RXNs: ['R09749']
# Failed to retrieve data for EC number: 1.1.1.-, Status code: 404
# EC: 1.8.5.7 -> RXNs: ['R11659']
# EC: 4.2.1.9 -> RXNs: ['R01209', 'R04441', 'R05070']
# EC: 2.2.1.6 -> RXNs: ['R00006', 'R00226', 'R00014', 'R03050', 'R04672', 'R04673', 'R08648']
# EC: 2.2.1.6 -> RXNs: ['R00006', 'R00226', 'R00014', 'R03050', 'R04672', 'R04673', 'R08648']
# EC: 1.1.1.86 -> RXNs: ['R04439', 'R03051', 'R04440', 'R05068', 'R05069', 'R05071']
# EC: 1.1.1.95 -> RXNs: ['R01513', 'R08198']
# EC: 1.1.1.85 -> RXNs: ['R01652', 'R04426', 'R10052', 'R00994']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 5.4.4.2 -> RXNs: ['R01717']
# EC: 6.1.1.17 -> RXNs: ['R05578']
# EC: 2.4.1.1 -> RXNs: ['R01821', 'R06050', 'R02111', 'R06185']
# EC: 3.1.2.6 -> RXNs: ['R04090', 'R01736']
# EC: 4.2.1.33 -> RXNs: ['R03968', 'R04001', 'R10170']
# EC: 4.2.1.33 -> RXNs: ['R03968', 'R04001', 'R10170']
# EC: 3.6.1.69 -> RXNs: ['R12532', 'R12533']
# EC: 1.1.1.94 -> RXNs: ['R00842', 'R00844']
# EC: 6.3.2.4 -> RXNs: ['R01150']
# EC: 2.7.4.16 -> RXNs: ['R00617']
# No relevant text found for EC number: 3.2.2.27
# EC: 2.7.2.18 -> RXNs: ['R12793']
# No relevant text found for EC number: 5.6.2.4
# EC: 2.1.1.171 -> RXNs: ['R07234']
# EC: 2.7.7.3 -> RXNs: ['R03035']
# No relevant text found for EC number: 7.4.2.1
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# Failed to retrieve data for EC number: 2.7.1.-, Status code: 404
# EC: 2.7.1.24 -> RXNs: ['R00130']
# EC: 3.2.2.2 3.2.2.3 -> RXNs: ['R01770']
# EC: 2.7.1.15 -> RXNs: ['R01051', 'R02750']
# EC: 1.6.5.2 -> RXNs: ['R07358', 'R02964', 'R03643', 'R03816', 'R07359']
# No relevant text found for EC number: 7.6.2.10
# EC: 3.1.4.46 -> RXNs: ['R00857', 'R01030', 'R01470']
# EC: 6.1.1.20 -> RXNs: ['R03660']
# EC: 6.1.1.20 -> RXNs: ['R03660']
# EC: 1.2.1.38 -> RXNs: ['R03443']
# EC: 2.3.1.1 -> RXNs: ['R00259']
# EC: 2.7.2.8 -> RXNs: ['R02649']
# EC: 2.6.1.11 -> RXNs: ['R02283']
# EC: 2.1.3.3 -> RXNs: ['R01398']
# EC: 6.3.4.5 -> RXNs: ['R01954']
# EC: 4.3.2.1 -> RXNs: ['R01086']
# EC: 6.1.1.1 -> RXNs: ['R02918']
# EC: 3.1.3.21 -> RXNs: ['R08658', 'R00841', 'R07298']
# No relevant text found for EC number: 2.1.1.226 2.1.1.227
# EC: 2.7.1.23 -> RXNs: ['R00104']
# EC: 6.3.4.2 -> RXNs: ['R00256', 'R00571', 'R00573']
# EC: 3.6.1.58 -> RXNs: ['R09877', 'R12595']
# EC: 2.8.1.1 2.8.1.2 -> RXNs: ['R01931']
# No relevant text found for EC number: 5.4.99.22
# EC: 2.7.4.25 -> RXNs: ['R00512', 'R01665']
# No relevant text found for EC number: 7.4.2.8
# No relevant text found for EC number: 3.6.4.13
# EC: 1.1.1.44 -> RXNs: ['R01528']
# No relevant text found for EC number: 7.3.2.2
# No relevant text found for EC number: 7.3.2.2
# No relevant text found for EC number: 7.3.2.2
# EC: 2.7.1.49 -> RXNs: ['R03471']
# EC: 2.7.1.50 -> RXNs: ['R04448']
# EC: 1.6.5.9 -> RXNs: ['R07358', 'R02163']
# EC: 2.1.1.79 -> RXNs: ['R03411']
# EC: 2.4.1.83 -> RXNs: ['R01009']
# No relevant text found for EC number: 2.3.1.269
# EC: 3.1.1.3 -> RXNs: ['R01369', 'R02250', 'R02687', 'R02688', 'R05209']
# EC: 1.14.13.83 -> RXNs: ['R05217']
# EC: 2.1.1.132 2.1.1.289 2.1.1.196 -> RXNs: ['R05149']
# No relevant text found for EC number: 5.6.2.6
# EC: 6.3.1.19 -> RXNs: ['R11207']
# EC: 3.5.1.119 -> RXNs: ['R11209', 'R11208']
# No relevant text found for EC number: 5.6.1.5
# No relevant text found for EC number: 2.1.1.219 2.1.1.220
# EC: 4.3.1.1 -> RXNs: ['R00490']
# EC: 2.4.2.17 -> RXNs: ['R01071']
# EC: 3.6.1.31 -> RXNs: ['R04035']
# EC: 2.1.1.13 -> RXNs: ['R00946', 'R09365']
# No relevant text found for EC number: 2.8.4.2
# EC: 1.20.4.4 -> RXNs: ['R10927']
# EC: 6.3.1.13 -> RXNs: ['R09591']
# EC: 3.6.1.27 -> RXNs: ['R05627']
# EC: 1.3.5.2 -> RXNs: ['R01868']
# Failed to retrieve data for EC number: 3.6.5.-, Status code: 404
# EC: 5.4.99.2 -> RXNs: ['R00833']
# EC: 5.4.99.2 -> RXNs: ['R00833']
# EC: 4.98.1.1 -> RXNs: ['R00310']
# Failed to retrieve data for EC number: 3.4.-.-, Status code: 404
# EC: 4.2.1.3 4.2.1.99 -> RXNs: ['R01324', 'R01325', 'R01900']
# EC: 6.3.5.2 -> RXNs: ['R00256', 'R01230', 'R01231', 'R08244']
# No relevant text found for EC number: 3.2.1.18
# EC: 2.8.1.7 -> RXNs: ['R07460', 'R11528', 'R11529']
# Failed to retrieve data for EC number: 2.4.1.-, Status code: 404
# EC: 1.17.99.9 -> RXNs: ['R07412', 'R12682', 'R12683']
# EC: 1.6.5.5 -> RXNs: ['R02364']
# EC: 2.5.1.141 -> RXNs: ['R07411']
# EC: 2.2.1.1 -> RXNs: ['R01641', 'R01067', 'R01830', 'R06590', 'R06861', 'R06863']
# EC: 2.2.1.2 -> RXNs: ['R08575', 'R01827']
# EC: 1.1.1.49 1.1.1.363 -> RXNs: ['R00835', 'R02736']
# EC: 3.1.1.31 -> RXNs: ['R02035']
# EC: 1.5.3.2 -> RXNs: ['R01264']
# EC: 4.1.1.31 -> RXNs: ['R00345']
# EC: 5.3.1.1 -> RXNs: ['R01015']
# EC: 2.7.2.3 -> RXNs: ['R01512']
# EC: 1.2.1.12 -> RXNs: ['R01061']
# EC: 2.5.1.78 -> RXNs: ['R04457']
# EC: 3.5.4.25 -> RXNs: ['R00425']
# EC: 2.5.1.9 -> RXNs: ['R00066']
# EC: 1.1.1.193 -> RXNs: ['R03458']
# EC: 5.1.3.1 -> RXNs: ['R01529']
# No relevant text found for EC number: 2.1.1.176
# EC: 2.1.2.9 -> RXNs: ['R03940']
# EC: 3.5.1.88 -> RXNs: ['R05635', 'R04268']
# No relevant text found for EC number: 5.6.2.4
# EC: 2.5.1.6 -> RXNs: ['R00177', 'R04771']
# EC: 4.1.1.36 -> RXNs: ['R03269']
# EC: 2.7.7.6 -> RXNs: ['R00444', 'R00435', 'R00441', 'R00442', 'R00443', 'R10813']
# EC: 2.7.4.8 -> RXNs: ['R00332', 'R02090', 'R12852']
# EC: 4.1.1.23 -> RXNs: ['R00965']
# EC: 6.3.5.5 -> RXNs: ['R00256', 'R00575', 'R01395', 'R10948', 'R10949', 'R07641']
# EC: 6.3.5.5 -> RXNs: ['R00256', 'R00575', 'R01395', 'R10948', 'R10949', 'R07641']
# EC: 3.5.2.3 -> RXNs: ['R01993']
# EC: 2.1.3.2 -> RXNs: ['R01397']
# EC: 2.4.2.9 -> RXNs: ['R00966']
# No relevant text found for EC number: 3.4.11.9
# EC: 4.2.3.4 -> RXNs: ['R03083']
# EC: 2.7.1.71 -> RXNs: ['R02412']
# EC: 4.2.3.5 -> RXNs: ['R01714']
# Failed to retrieve data for EC number: 7.2.2.-, Status code: 404
# EC: 1.1.1.25 -> RXNs: ['R02413', 'R12885']
# EC: 4.2.2.29 -> RXNs: ['R13248']
# No relevant text found for EC number: 3.1.21.10
# EC: 6.1.1.7 -> RXNs: ['R03038']
# EC: 6.1.1.12 -> RXNs: ['R05577']
# EC: 1.5.1.38 -> RXNs: ['R05706']
# EC: 4.3.1.17 -> RXNs: ['R00220', 'R00590', 'R11099', 'R11100', 'R06131']
# EC: 1.1.5.3 -> RXNs: ['R00849', 'R08657', 'R00848']
# EC: 6.1.1.21 -> RXNs: ['R03655']
# EC: 3.1.2.6 -> RXNs: ['R04090', 'R01736']
# EC: 5.2.1.8 -> RXNs: ['R04273']
# EC: 2.7.6.5 -> RXNs: ['R00429']
# EC: 2.4.2.7 -> RXNs: ['R00190', 'R04378']
# No relevant text found for EC number: 3.6.4.12
# No relevant text found for EC number: 3.6.4.12
# No relevant text found for EC number: 3.1.21.10
# Failed to retrieve data for EC number: 3.1.2.-, Status code: 404
# EC: 2.4.1.345 -> RXNs: ['R11702', 'R12038']
# EC: 2.3.1.265 -> RXNs: ['R11781', 'R11782', 'R12039', 'R12042']
# Failed to retrieve data for EC number: 2.7.8.-, Status code: 404
# EC: 2.7.7.53 -> RXNs: ['R00126', 'R01618']
# EC: 6.1.1.3 -> RXNs: ['R03663']
# EC: 1.11.1.19 -> RXNs: ['R10915']
# No relevant text found for EC number: 2.4.2.47
# EC: 1.8.4.12 -> RXNs: ['R07607']
# EC: 1.3.98.5 -> RXNs: ['R11522', 'R12454', 'R12455']
# No relevant text found for EC number: 3.1.13.5
# EC: 2.2.1.7 -> RXNs: ['R05636']
# EC: 3.6.1.23 -> RXNs: ['R02100', 'R11896']
# EC: 3.1.3.25 -> RXNs: ['R07343', 'R01185', 'R01186', 'R01187']
# EC: 2.7.1.63 -> RXNs: ['R02185', 'R02187', 'R02189']
# No relevant text found for EC number: 3.1.1.96
# EC: 5.1.3.2 -> RXNs: ['R00291', 'R00418', 'R02984']
# No relevant text found for EC number: 3.6.4.13
# No relevant text found for EC number: 3.4.21.88
# EC: 2.7.1.56 -> RXNs: ['R13203', 'R02071', 'R03236']
# EC: 2.7.3.9 -> RXNs: ['R02628']
# EC: 2.7.1.56 -> RXNs: ['R13203', 'R02071', 'R03236']
# EC: 2.7.1.202 -> RXNs: ['R03232']
# EC: 5.1.1.7 -> RXNs: ['R02735']
# EC: 2.5.1.75 -> RXNs: ['R01122']
# EC: 2.8.4.3 -> RXNs: ['R10645', 'R10646', 'R10647']
# No relevant text found for EC number: 7.4.2.1
# Failed to retrieve data for EC number: 7.6.2.-, Status code: 404
# EC: 3.5.1.42 -> RXNs: ['R02322', 'R06134']
# EC: 2.7.8.5 -> RXNs: ['R01801']
# Failed to retrieve data for EC number: 3.1.-.-, Status code: 404
# EC: 4.3.3.7 -> RXNs: ['R10147']
# EC: 2.1.1.148 -> RXNs: ['R06613']
# EC: 1.17.1.8 -> RXNs: ['R04198', 'R04199']
# EC: 2.7.7.8 -> RXNs: ['R07282', 'R00437', 'R00438', 'R00439', 'R00440']
# EC: 2.7.1.26 -> RXNs: ['R00549']
# No relevant text found for EC number: 5.4.99.25
# EC: 6.3.2.14 2.7.8.7 -> RXNs: ['R07644']
# EC: 3.1.3.7 -> RXNs: ['R00188', 'R00508']
# EC: 6.1.1.15 -> RXNs: ['R03661']
# EC: 6.6.1.1 -> RXNs: ['R03877']
# EC: 2.1.1.107 -> RXNs: ['R03194', 'R07237', 'R07238', 'R03950']
# No relevant text found for EC number: 2.7.7.108
# EC: 1.1.5.4 -> RXNs: ['R00361', 'R00360', 'R01257']
# EC: 1.8.1.15 -> RXNs: ['R05715', 'R05716', 'R06289', 'R06290']
# No relevant text found for EC number: 3.4.11.18
# Failed to retrieve data for EC number: 7.6.2.-, Status code: 404
# EC: 1.17.7.1 -> RXNs: ['R08689']
# EC: 1.1.1.267 -> RXNs: ['R05688']
# No relevant text found for EC number: 2.1.1.192
# EC: 2.7.7.41 -> RXNs: ['R01799']
# EC: 2.7.4.22 -> RXNs: ['R00158']
# No relevant text found for EC number: 3.5.1.28
# No relevant text found for EC number: 3.1.26.4
# No relevant text found for EC number: 3.4.21.89
# EC: 2.5.1.3 -> RXNs: ['R03223', 'R10712', 'R11312']
# EC: 1.4.3.19 -> RXNs: ['R00366', 'R07463', 'R10245', 'R05861', 'R05862', 'R05863']
# EC: 2.8.1.10 -> RXNs: ['R10247']
# EC: 2.7.7.80 2.7.7.- 2.8.1.11 2.8.1.- -> RXNs: ['R07459']
# EC: 5.5.1.2 -> RXNs: ['R03307']
# EC: 2.1.1.228 -> RXNs: ['R00597']
# EC: 3.6.5.4 -> RXNs: ['R00335']
# EC: 2.7.7.59 -> RXNs: ['R04733']
# EC: 3.6.1.7 -> RXNs: ['R00539', 'R00317', 'R01421', 'R01515']
# No relevant text found for EC number: 3.2.2.23
# No relevant text found for EC number: 3.1.26.3
# EC: 1.4.1.4 -> RXNs: ['R00248', 'R00145', 'R00146']
# EC: 2.7.1.165 -> RXNs: ['R08572']
# EC: 1.13.11.2 -> RXNs: ['R00816', 'R04089', 'R05295', 'R05404', 'R05406', 'R07795']
# EC: 2.7.1.40 -> RXNs: ['R00200', 'R00430', 'R00572', 'R00659', 'R00724', 'R01138', 'R01858', 'R02320']
# No relevant text found for EC number: 2.5.1.145
# EC: 4.1.1.48 -> RXNs: ['R03508']
# EC: 3.5.4.19 -> RXNs: ['R04037']
# EC: 4.3.2.10 -> RXNs: ['R00256', 'R04558', 'R12152']
# EC: 3.1.3.25 -> RXNs: ['R07343', 'R01185', 'R01186', 'R01187']
# EC: 5.3.1.16 -> RXNs: ['R04640']
# EC: 4.3.2.10 -> RXNs: ['R00256', 'R04558', 'R12152']
# No relevant text found for EC number: 3.1.21.3
# EC: 2.1.1.72 -> RXNs: ['R02961']
# EC: 4.2.1.19 -> RXNs: ['R03457']
# EC: 2.6.1.9 -> RXNs: ['R03243', 'R00694', 'R00734']
# EC: 1.1.1.23 -> RXNs: ['R01158', 'R01163', 'R03012']
# No relevant text found for EC number: 3.2.1.68
# EC: 5.3.1.22 -> RXNs: ['R01394']
# EC: 1.1.1.18 1.1.1.369 -> RXNs: ['R01183']
# No relevant text found for EC number: 7.6.2.8
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 5.4.99.15 -> RXNs: ['R01824', 'R06243']
# No relevant text found for EC number: 3.2.1.141
# EC: 4.3.1.19 -> RXNs: ['R00996', 'R11098', 'R11101', 'R00220', 'R06131']
# EC: 2.1.1.14 -> RXNs: ['R04405', 'R09365']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# No relevant text found for EC number: 5.4.99.23
# No relevant text found for EC number: 3.4.23.36
# EC: 3.5.1.1 -> RXNs: ['R00485', 'R06134']
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 6.1.1.5 -> RXNs: ['R03656']
# EC: 2.4.2.1 2.4.2.28 3.5.4.4 -> RXNs: ['R08368', 'R01561', 'R01863', 'R02147', 'R02297', 'R10244', 'R01969', 'R02557', 'R02748', 'R02294', 'R02295']
# EC: 6.3.2.8 -> RXNs: ['R03193']
# EC: 2.4.1.227 -> RXNs: ['R05662', 'R06173', 'R05032', 'R06172', 'R06174']
# EC: 6.3.2.9 -> RXNs: ['R02783']
# EC: 2.7.8.13 -> RXNs: ['R05629', 'R05630']
# EC: 6.3.2.10 -> RXNs: ['R04573', 'R04617']
# EC: 6.3.2.13 -> RXNs: ['R02788']
# No relevant text found for EC number: 3.4.16.4
# No relevant text found for EC number: 2.1.1.199
# EC: 1.5.1.20 -> RXNs: ['R01224', 'R07168']
# EC: 2.5.1.1 2.5.1.10 2.5.1.29 -> RXNs: ['R01658']
# Failed to retrieve data for EC number: 2.4.1.-, Status code: 404
# EC: 2.7.11.1 -> RXNs: ['R00162', 'R03632']
# EC: 2.5.1.54 -> RXNs: ['R01826']
# Failed to retrieve data for EC number: 2.4.1.-, Status code: 404
# EC: 2.3.1.51 -> RXNs: ['R02241', 'R02760', 'R09381']
# EC: 2.7.1.2 -> RXNs: ['R00299', 'R01600', 'R01786']
# EC: 2.4.1.346 -> RXNs: ['R11703', 'R11704', 'R12040', 'R12041']
# Failed to retrieve data for EC number: 3.4.-.-, Status code: 404
# EC: 7.1.1.8 -> RXNs: ['R13224', 'R02161']
# EC: 7.1.1.8 -> RXNs: ['R13224', 'R02161']
# EC: 7.1.1.8 -> RXNs: ['R13224', 'R02161']
# EC: 7.1.1.9 -> RXNs: ['R00081', 'R00082']
# EC: 7.1.1.9 -> RXNs: ['R00081', 'R00082']
# EC: 7.1.1.9 -> RXNs: ['R00081', 'R00082']
# EC: 6.3.5.4 -> RXNs: ['R00256', 'R00483', 'R00578']
# EC: 2.7.1.156 -> RXNs: ['R05221', 'R06558']
# EC: 2.4.2.21 -> RXNs: ['R04148']
# EC: 2.7.8.26 -> RXNs: ['R05223', 'R11174']
# EC: 2.6.1.42 -> RXNs: ['R01090', 'R01214', 'R02199', 'R10991']
# No relevant text found for EC number: 3.4.11.1
# EC: 2.3.1.12 -> RXNs: ['R02569']
# EC: 2.3.1.181 -> RXNs: ['R07766', 'R12427', 'R12428', 'R07769']
# EC: 2.8.1.8 -> RXNs: ['R07767', 'R12423', 'R12424']
# EC: 6.3.1.2 -> RXNs: ['R00253']
# EC: 4.2.3.1 -> RXNs: ['R01466', 'R05086']
# EC: 1.14.15.20 -> RXNs: ['R11579']
# EC: 2.7.7.42 -> RXNs: ['R03473']
# EC: 6.3.1.2 -> RXNs: ['R00253']
# EC: 2.7.1.6 -> RXNs: ['R01092']
# EC: 3.1.26.4 3.1.3.73 -> RXNs: ['R04594', 'R11173']
# EC: 3.1.3.18 -> RXNs: ['R01334']
# EC: 3.1.3.48 -> RXNs: ['R02585']
# EC: 1.2.4.1 -> RXNs: ['R01699', 'R00014', 'R03270']
# EC: 3.1.3.5 -> RXNs: ['R07297', 'R00183', 'R00511', 'R00963', 'R01126', 'R01227', 'R02323', 'R02719', 'R03346', 'R01569', 'R01664', 'R01968', 'R02088', 'R02102', 'R12958']
# EC: 3.1.1.103 -> RXNs: ['R11965']
# EC: 3.1.3.1 -> RXNs: ['R00626', 'R02135', 'R03024', 'R01010', 'R04620']
# No relevant text found for EC number: 2.7.7.101
# No relevant text found for EC number: 4.6.1.24
# EC: 2.6.1.16 -> RXNs: ['R00768']
# EC: 3.1.5.1 -> RXNs: ['R01856']
# EC: 6.1.1.14 -> RXNs: ['R03654']
# EC: 2.5.1.31 -> RXNs: ['R06447']
# No relevant text found for EC number: 2.1.1.193
# EC: 6.2.1.3 -> RXNs: ['R00390', 'R01280']
# No relevant text found for EC number: 2.4.1.25
# No relevant text found for EC number: 3.4.15.5
# EC: 5.4.99.16 -> RXNs: ['R01557', 'R06218']
# EC: 5.3.3.2 -> RXNs: ['R01123']
# EC: 4.4.1.13 -> RXNs: ['R12188', 'R01286', 'R02408', 'R02953', 'R03528', 'R00782', 'R04941', 'R09366']
# EC: 3.1.4.58 -> RXNs: ['R11786']
# EC: 2.7.1.15 -> RXNs: ['R01051', 'R02750']
# EC: 5.1.3.15 -> RXNs: ['R02739']
# EC: 2.3.3.9 -> RXNs: ['R00472']
# EC: 4.1.3.1 -> RXNs: ['R00479']
# Failed to retrieve data for EC number: 3.6.5.n1, Status code: 400
# EC: 2.7.7.7 -> RXNs: ['R00379', 'R00375', 'R00376', 'R00377', 'R00378', 'R11029']
# EC: 3.1.3.85 -> RXNs: ['R09664']
# EC: 2.7.7.18 -> RXNs: ['R03005', 'R00137']
# EC: 1.2.1.41 -> RXNs: ['R03313']
# EC: 2.7.2.11 -> RXNs: ['R00239']
# Failed to retrieve data for EC number: 3.6.5.-, Status code: 404
# EC: 1.1.1.346 -> RXNs: ['R08878']
# No relevant text found for EC number: 3.1.26.12
# EC: 1.13.11.24 -> RXNs: ['R02156']
# EC: 2.7.4.6 -> RXNs: ['R00331', 'R00124', 'R00139', 'R00156', 'R00330', 'R00570', 'R00722', 'R01137', 'R01857', 'R02093', 'R02326', 'R02331', 'R03530', 'R12853', 'R11894', 'R11895']
# EC: 6.3.2.12 6.3.2.17 -> RXNs: ['R02237', 'R01654']
# EC: 6.1.1.9 -> RXNs: ['R03665']
# EC: 1.1.1.37 -> RXNs: ['R00342', 'R07136']
# EC: 1.14.13.82 -> RXNs: ['R05274']
# EC: 2.8.3.5 -> RXNs: ['R01780', 'R00410']
# EC: 2.8.3.5 -> RXNs: ['R01780', 'R00410']
# EC: 2.3.1.9 -> RXNs: ['R00238', 'R00927', 'R01177']
# EC: 3.1.1.24 -> RXNs: ['R02991']
# EC: 4.1.1.44 -> RXNs: ['R03470']
# EC: 5.5.1.2 -> RXNs: ['R03307']
# EC: 1.13.11.3 -> RXNs: ['R01631', 'R03549']
# EC: 1.13.11.3 -> RXNs: ['R01631', 'R03549']
# EC: 5.3.3.4 -> RXNs: ['R06990', 'R04260']
# EC: 5.5.1.1 -> RXNs: ['R03959', 'R06989', 'R05300', 'R05390', 'R08116', 'R09229']
# EC: 1.13.11.1 -> RXNs: ['R00817', 'R04258', 'R05299', 'R08114', 'R08115', 'R09134']
# EC: 1.14.12.10 -> RXNs: ['R07188', 'R05621', 'R05622', 'R08100', 'R08101', 'R08108', 'R08109', 'R08110']
# EC: 1.14.12.10 -> RXNs: ['R07188', 'R05621', 'R05622', 'R08100', 'R08101', 'R08108', 'R08109', 'R08110']
# Failed to retrieve data for EC number: 1.18.1.-, Status code: 404
# EC: 1.3.1.25 -> RXNs: ['R00813', 'R08111', 'R08112', 'R08113']
# No relevant text found for EC number: 3.4.21.92
# No relevant text found for EC number: 3.4.21.92
# EC: 5.2.1.8 -> RXNs: ['R04273']
# EC: 5.3.1.6 -> RXNs: ['R01056', 'R09030']
# No relevant text found for EC number: 3.4.11.2
# EC: 2.6.1.55 -> RXNs: ['R01684', 'R00908']
# EC: 2.5.1.48 -> RXNs: ['R03260', 'R00999', 'R01288', 'R02508', 'R03217', 'R04944', 'R04945', 'R04946']
# Failed to retrieve data for EC number: 7.2.2.-, Status code: 404
# Failed to retrieve data for EC number: 3.1.2.-, Status code: 404
# EC: 3.1.3.1 -> RXNs: ['R00626', 'R02135', 'R03024', 'R01010', 'R04620']
# Failed to retrieve data for EC number: 7.5.2.-, Status code: 404
# EC: 2.5.1.143 -> RXNs: ['R12017']
# EC: 5.3.1.35 -> RXNs: ['R11721', 'R11722']
# Failed to retrieve data for EC number: 3.1.-.-, Status code: 404
# EC: 3.5.1.2 -> RXNs: ['R00256', 'R01579', 'R06134']
# EC: 5.3.1.12 -> RXNs: ['R01482', 'R01983']
# EC: 2.7.1.12 -> RXNs: ['R01737']
# EC: 3.5.1.19 3.5.1.- -> RXNs: ['R01268', 'R06134']
# EC: 1.11.1.24 -> RXNs: ['R12570']
# EC: 2.7.8.7 -> RXNs: ['R01625']
# Failed to retrieve data for EC number: 2.3.1.-, Status code: 404
# EC: 1.1.1.30 -> RXNs: ['R01361']
# EC: 3.6.1.66 -> RXNs: ['R00720', 'R02720', 'R03531', 'R08243']
# EC: 2.7.7.56 -> RXNs: ['R07285']
# EC: 5.1.1.3 -> RXNs: ['R00260']
# No relevant text found for EC number: 3.4.21.105
# EC: 6.3.4.21 -> RXNs: ['R01724']
# No relevant text found for EC number: 3.6.4.12
# EC: 3.1.3.3 -> RXNs: ['R00582', 'R02853']
# EC: 7.1.1.9 -> RXNs: ['R00081', 'R00082']
# EC: 1.17.4.1 -> RXNs: ['R04294', 'R02017', 'R02018', 'R02019', 'R02024', 'R08363', 'R08364', 'R11893']
# EC: 1.16.3.2 -> RXNs: ['R13250', 'R13251', 'R13252']
# EC: 1.17.4.1 -> RXNs: ['R04294', 'R02017', 'R02018', 'R02019', 'R02024', 'R08363', 'R08364', 'R11893']
# EC: 6.3.1.5 -> RXNs: ['R00189']
# Failed to retrieve data for EC number: 1.3.1.-, Status code: 404
# EC: 4.2.1.79 -> RXNs: ['R04424']
# EC: 4.4.1.19 -> RXNs: ['R07476']
# EC: 5.4.2.2 -> RXNs: ['R08639', 'R00959', 'R01057', 'R03319']
# EC: 2.5.1.7 -> RXNs: ['R00660']
# EC: 2.5.1.17 -> RXNs: ['R12183', 'R12184', 'R01492', 'R05220', 'R07268']
# EC: 2.5.1.47 -> RXNs: ['R00897', 'R03601', 'R04859', 'R07274']
# EC: 2.3.1.30 -> RXNs: ['R00586']
# EC: 6.2.1.5 -> RXNs: ['R00405', 'R02404']
# EC: 6.2.1.5 -> RXNs: ['R00405', 'R02404']
# EC: 2.8.3.18 -> RXNs: ['R10343']
# No relevant text found for EC number: 7.3.2.1
# EC: 2.3.1.189 -> RXNs: ['R09622']
# EC: 4.1.3.38 -> RXNs: ['R05553']
# EC: 6.3.3.1 -> RXNs: ['R04208']
# EC: 2.4.2.14 -> RXNs: ['R01072']
# EC: 6.3.5.3 -> RXNs: ['R04463']
# EC: 6.3.5.3 3.5.1.2 -> RXNs: ['R04463']
# EC: 6.3.5.3 -> RXNs: ['R04463']
# EC: 1.11.1.9 -> RXNs: ['R00274']
# No relevant text found for EC number: 3.4.21.83
# EC: 6.3.2.6 -> RXNs: ['R04591']
# EC: 4.3.2.2 -> RXNs: ['R01083', 'R04559', 'R12851']
# EC: 6.3.4.13 -> RXNs: ['R04144']
# EC: 2.6.1.62 -> RXNs: ['R03231']
# EC: 6.3.3.3 -> RXNs: ['R03182', 'R12933', 'R12934']
# EC: 1.2.5.1 -> RXNs: ['R03145']
# EC: 1.4.1.16 -> RXNs: ['R02755']
# EC: 2.4.1.15 2.4.1.347 -> RXNs: ['R00836', 'R06043', 'R02737', 'R06226']
# EC: 3.1.3.12 -> RXNs: ['R02778', 'R06228']
# EC: 1.1.1.335 -> RXNs: ['R10140']
# No relevant text found for EC number: 2.1.1.185
# EC: 6.1.1.16 -> RXNs: ['R03650']
# EC: 2.7.1.211 -> RXNs: ['R00811']
# No relevant text found for EC number: 3.2.1.26
# EC: 3.5.99.6 -> RXNs: ['R00765']
# EC: 3.5.1.25 -> RXNs: ['R02059', 'R05168']
# EC: 2.7.1.2 -> RXNs: ['R00299', 'R01600', 'R01786']
# EC: 5.1.3.9 -> RXNs: ['R02770', 'R02087']
# EC: 4.6.1.12 -> RXNs: ['R05637']
# EC: 2.7.7.60 -> RXNs: ['R05633']
# No relevant text found for EC number: 2.7.13.3
# EC: 2.7.7.85 -> RXNs: ['R10342']
# EC: 1.2.1.3 -> RXNs: ['R00538', 'R00631', 'R00710', 'R00904', 'R01752', 'R02549', 'R02678', 'R02940', 'R03283', 'R03869', 'R04065', 'R04506', 'R04903', 'R05050', 'R05286', 'R06366', 'R08146', 'R00264', 'R01986', 'R02957', 'R05237', 'R05238']
# EC: 4.2.1.1 -> RXNs: ['R00132', 'R10092']
# No relevant text found for EC number: 3.2.2.31
# EC: 1.1.1.- 1.1.1.76 1.1.1.304 -> RXNs: ['R03707']
# EC: 1.7.1.7 -> RXNs: ['R01134']
# EC: 1.14.13.7 -> RXNs: ['R00815', 'R03566', 'R03568']
# EC: 6.1.1.6 -> RXNs: ['R03658']
# EC: 6.3.2.1 -> RXNs: ['R02473']
# EC: 2.7.6.3 -> RXNs: ['R03503']
# EC: 4.1.2.25 -> RXNs: ['R03504']
# EC: 2.5.1.15 -> RXNs: ['R03067', 'R03066']
# EC: 3.5.4.16 -> RXNs: ['R00424', 'R00428', 'R04639', 'R05046', 'R05048']
# Failed to retrieve data for EC number: 3.4.24.-, Status code: 404
# EC: 2.4.2.8 -> RXNs: ['R01132', 'R01229', 'R02142', 'R08237', 'R08238', 'R08245']
# EC: 6.3.4.19 -> RXNs: ['R09597']
# No relevant text found for EC number: 3.4.16.4
# EC: 3.6.1.1 -> RXNs: ['R00004']
# EC: 2.5.1.16 -> RXNs: ['R01920', 'R08359']
# EC: 1.18.1.3 -> RXNs: ['R05875', 'R02000']
# EC: 2.8.1.1 -> RXNs: ['R01931']
# EC: 1.2.1.79 -> RXNs: ['R00714']
# EC: 2.7.4.1 -> RXNs: ['R02184']
# No relevant text found for EC number: 5.6.1.7
# EC: 3.4.13.23 -> RXNs: ['R12514']
# EC: 6.3.2.2 -> RXNs: ['R00894', 'R10993']
# EC: 3.5.1.88 -> RXNs: ['R05635', 'R04268']
# EC: 2.3.1.1 -> RXNs: ['R00259']
# No relevant text found for EC number: 3.1.11.2
# Failed to retrieve data for EC number: 2.7.8.-, Status code: 404
# EC: 3.6.1.55 -> RXNs: ['R09832']
# EC: 2.7.11.1 -> RXNs: ['R00162', 'R03632']
# EC: 2.7.2.1 -> RXNs: ['R00315', 'R01353']
# EC: 2.3.1.8 -> RXNs: ['R00230', 'R00921']
# EC: 1.18.1.2 1.19.1.1 -> RXNs: ['R01195', 'R10159']
# EC: 6.3.1.21 -> RXNs: ['R06974']
# EC: 6.3.4.4 -> RXNs: ['R01135']
# EC: 4.1.2.13 -> RXNs: ['R01068', 'R01070', 'R01829', 'R02568']
# EC: 2.4.2.10 -> RXNs: ['R01870', 'R08231']
# EC: 2.8.1.1 2.8.1.2 -> RXNs: ['R01931']
# EC: 3.5.1.128 -> RXNs: ['R12024']
# Failed to retrieve data for EC number: 1.2.1.-, Status code: 404
# EC: 3.2.2.9 -> RXNs: ['R00194', 'R01401', 'R12621']
# EC: 1.1.1.1 -> RXNs: ['R00623', 'R00754', 'R02124', 'R02878', 'R04805', 'R04880', 'R05233', 'R05234', 'R06917', 'R06927', 'R08281', 'R08306', 'R08557', 'R08558', 'R10783', 'R00624', 'R08310', 'R02246', 'R07105']
# EC: 4.99.1.3 -> RXNs: ['R05807']
# EC: 2.7.7.4 -> RXNs: ['R00529', 'R04929']
# EC: 2.7.7.4 -> RXNs: ['R00529', 'R04929']
# EC: 1.8.4.8 -> RXNs: ['R02021']
# EC: 1.8.7.1 -> RXNs: ['R00859', 'R03600']
# EC: 1.18.1.2 1.19.1.1 -> RXNs: ['R01195', 'R10159']
# EC: 3.2.2.1 -> RXNs: ['R02341', 'R01245', 'R01677', 'R01770', 'R02143']
# No relevant text found for EC number: 3.2.2.20
# EC: 1.14.12.17 -> RXNs: ['R05724', 'R05725']
# EC: 1.5.1.40 -> RXNs: ['R09749']
# EC: 2.6.1.66 2.6.1.2 -> RXNs: ['R01215']
# EC: 1.1.1.22 -> RXNs: ['R00286']
# EC: 3.5.4.13 -> RXNs: ['R02325']
# No relevant text found for EC number: 3.2.1.52
# Failed to retrieve data for EC number: 2.4.2.-, Status code: 404
# Failed to retrieve data for EC number: 2.3.1.-, Status code: 404
# EC: 4.1.1.32 -> RXNs: ['R00431', 'R00726']
# EC: 2.1.1.33 -> RXNs: ['R00600']
# Failed to retrieve data for EC number: 6.4.1.- 2.1.3.-, Status code: 404
# Failed to retrieve data for EC number: 6.2.1.-, Status code: 404
# Failed to retrieve data for EC number: 3.1.1.-, Status code: 404
# EC: 2.3.1.20 2.3.1.122 2.3.1.- -> RXNs: ['R02251', 'R02694', 'R09474']
# Failed to retrieve data for EC number: 2.4.2.-, Status code: 404
# EC: 2.4.2.45 -> RXNs: ['R10095']
# EC: 3.1.3.111 -> RXNs: ['R13371']
# EC: 2.4.1.288 -> RXNs: ['R12080']
# EC: 3.6.1.27 -> RXNs: ['R05627']
# EC: 5.4.99.9 -> RXNs: ['R00505', 'R09009']
# EC: 2.7.1.30 -> RXNs: ['R00847']
# EC: 6.1.1.11 -> RXNs: ['R03662', 'R08218']
# EC: 4.2.1.51 -> RXNs: ['R01373', 'R00691']
# EC: 3.1.4.46 -> RXNs: ['R00857', 'R01030', 'R01470']
# EC: 2.7.1.40 -> RXNs: ['R00200', 'R00430', 'R00572', 'R00659', 'R00724', 'R01138', 'R01858', 'R02320']
# EC: 1.1.1.27 -> RXNs: ['R00703', 'R01000', 'R03104']
# EC: 1.5.1.39 -> RXNs: ['R05705', 'R05706']
# EC: 1.1.2.3 -> RXNs: ['R00196']
# EC: 1.8.4.11 -> RXNs: ['R04120', 'R07606']
# EC: 1.15.1.1 -> RXNs: ['R00275']
# EC: 1.7.2.1 -> RXNs: ['R00783', 'R00784', 'R00280', 'R00785']
# No relevant text found for EC number: 3.4.22.70
# No relevant text found for EC number: 5.4.99.28 5.4.99.29
# EC: 1.16.1.1 -> RXNs: ['R02807']
# EC: 1.16.3.1 -> RXNs: ['R00078']
# No relevant text found for EC number: 7.2.2.9
# No relevant text found for EC number: 3.6.4.12
# EC: 1.14.99.57 -> RXNs: ['R11741', 'R11742']
# EC: 5.5.1.4 -> RXNs: ['R07324']
# No relevant text found for EC number: 3.2.2.23 4.2.99.18
# No relevant text found for EC number: 6.5.1.8
# EC: 2.1.1.63 -> RXNs: ['R04314']
# EC: 1.1.1.38 -> RXNs: ['R00214', 'R00217']
# EC: 2.7.1.12 -> RXNs: ['R01737']
# EC: 1.4.5.1 -> RXNs: ['R09493', 'R01374']
# EC: 1.1.1.298 -> RXNs: ['R09289']
# EC: 6.1.1.4 -> RXNs: ['R03657']
# EC: 5.2.1.4 -> RXNs: ['R03868']
# EC: 3.7.1.5 -> RXNs: ['R00543', 'R01085']
# EC: 1.13.11.4 -> RXNs: ['R02656']
# EC: 1.14.13.24 -> RXNs: ['R02589']
# EC: 4.1.3.27 -> RXNs: ['R00986', 'R00985']
# EC: 4.1.3.27 -> RXNs: ['R00986', 'R00985']
# EC: 2.4.2.18 -> RXNs: ['R01073']
# EC: 4.1.1.48 -> RXNs: ['R03508']
# EC: 4.2.1.20 -> RXNs: ['R00674', 'R02340', 'R02722']
# EC: 4.2.1.20 -> RXNs: ['R00674', 'R02340', 'R02722']
# EC: 2.7.1.194 -> RXNs: ['R07671']
# EC: 1.6.99.1 -> RXNs: ['R00282']
# EC: 1.13.11.37 -> RXNs: ['R04061', 'R03891']
# EC: 1.3.1.32 -> RXNs: ['R02988', 'R02989', 'R05355', 'R06848', 'R07781', 'R09137', 'R09138', 'R09223', 'R09224']
# EC: 1.1.1.18 -> RXNs: ['R01183']
# EC: 1.1.1.18 1.1.1.369 -> RXNs: ['R01183']
# EC: 3.6.1.31 -> RXNs: ['R04035']
# EC: 2.7.1.49 -> RXNs: ['R03471']
# EC: 3.5.1.59 -> RXNs: ['R01563']
# EC: 2.7.7.72 -> RXNs: ['R09382', 'R09383', 'R09384', 'R09386']
# EC: 1.8.1.9 -> RXNs: ['R02016', 'R00900', 'R03596', 'R09372']
# No relevant text found for EC number: 3.5.1.28
# No relevant text found for EC number: 2.1.1.170
# No relevant text found for EC number: 3.1.26.5
# Results saved to 14067map13032_R1.xlsx

# %% [markdown]
# 针对多个酶号的进行手动管理获取R{5}，并分开R

# %%
import pandas as pd

# 定义安全解析函数，将逗号分隔的字符串转换为列表
def safe_eval(val):
    if isinstance(val, str) and val.strip():  # 如果是非空字符串
        try:
            # 将逗号分隔的字符串转换为列表，并去除空格
            return [x.strip() for x in val.split(',')]
        except:
            return None  # 如果转换失败返回None
    elif isinstance(val, (int, float)):  # 如果是数字类型，直接转为单元素列表
        return [val]
    return None  # 如果是空值，返回None

# 读取数据
df = pd.read_excel('14067map13032_R1.xlsx')

# 应用 safe_eval 并过滤掉返回 None 的行
df['KEGG Rxn number'] = df['KEGG Rxn number'].apply(safe_eval)
df = df[df['KEGG Rxn number'].notna()]  # 只保留有值的行

# 使用 explode() 将 "KEGG Rxn number" 列展开成多行
df_exploded = df.explode('KEGG Rxn number', ignore_index=True)

# 清除空值行
df_exploded = df_exploded.dropna(subset=['KEGG Rxn number'])

# 保存结果到新的Excel文件
output_exploded_file = '2.Expand GEM/14067map13032_R2.xlsx'
df_exploded.to_excel(output_exploded_file, index=False)

print(f"已完成处理并保存到 {output_exploded_file} 文件")
# Out:
# 已完成处理并保存到 14067map13032_R2.xlsx 文件

# %% [markdown]
# # 根据R{5}匹配modelseed rxn

# %%
import pandas as pd

# 读取xlsx文件
xlsx_file = '2.Expand GEM/14067map13032_R2.xlsx'  # 请替换为您的xlsx文件路径
df_xlsx = pd.read_excel(xlsx_file)

# 读取tsv文件
tsv_file = '4. add linker/modelseed_reactions.tsv'  # 请替换为您的tsv文件路径
df_tsv = pd.read_csv(tsv_file, sep='\t')

# 筛选出status列为OK的记录
df_tsv_ok = df_tsv[df_tsv['status'] == 'OK']

# 根据abbreviation和KEGG Rxn number进行匹配
# 这里假设xlsx文件中的KEGG Rxn number列名为'KEGG_Rxn_number'
# 假设tsv文件中的abbreviation列名为'abbreviation'
merged_df = pd.merge(df_xlsx, df_tsv_ok, left_on='KEGG Rxn number', right_on='abbreviation', how='left')

# 处理deltaG数据，将deltag和deltagerr拼接成新的列
merged_df['deltaG'] = merged_df['deltag'].astype(str) + '±' + merged_df['deltagerr'].astype(str) + ' (kcal/mol)'

# 选择需要的列，并重新排列
final_columns = df_xlsx.columns.tolist() + ['id', 'name', 'equation', 'definition', 'pathways', 'deltaG']
merged_df = merged_df[final_columns]
# 输出为新的xlsx文件
output_file = '14067map13032_rxn.xlsx'  # 请替换为您希望保存的输出文件路径
merged_df.to_excel(output_file, index=False)

print(f"合并完成，结果已保存到 {output_file}")
# Out:
# 合并完成，结果已保存到 14067map13032_rxn.xlsx

# %% [markdown]
# # 将相同的反应合并起来

# %%
import pandas as pd

# 读取xlsx文件
xlsx_file = '2.Expand GEM/14067map13032_rxn1.xlsx'  # 请替换为您的xlsx文件路径
df = pd.read_excel(xlsx_file)

# 删除id列为空的行
df_cleaned = df.dropna(subset=['id'])

# 按id列分组，将同一个id的行合并
def merge_values(series):
    # 对于不同的值，用'//'连接
    return '//'.join(series.astype(str).unique())

# 对所有列进行处理，将同一id下不同的值合并
df_merged = df_cleaned.groupby('id', as_index=False).agg(merge_values)

# 输出合并后的文件
output_file = '2.Expand GEM/14067map13032_rxn2.xlsx'  # 请替换为您希望保存的输出文件路径
df_merged.to_excel(output_file, index=False)

print(f"数据处理完成，结果已保存到 {output_file}")
# Out:
# 数据处理完成，结果已保存到 14067map13032_rxn2.xlsx

# %% [markdown]
# 手动处理列表中的GPR

# %% [markdown]
# # 将检索到的rxn添加到模型中，扩展GEM

# %%
import pandas as pd

# 读取原始xlsx文件
original_file = '2.Expand GEM/14067map13032_rxn2.xlsx'  # 替换为你的文件路径
df_original = pd.read_excel(original_file)

# 提取相关列，并修改ID格式
df_original = df_original[['id', 'locus_tag', 'name', 'equation', 'definition']]
df_original['id'] = df_original['id'].apply(lambda x: f"{x}_c0" if isinstance(x, str) and x.startswith('rxn') else x)

# 读取14067_rxn_1.xlsx文件
rxn_file = '2.Expand GEM/14067_rxn_1.xlsx'  # 替换为你的文件路径
df_rxn = pd.read_excel(rxn_file)

# 将ID列中的数据转换为字符串并检查哪些ID在原文件中不存在
missing_rxns = df_original[~df_original['id'].isin(df_rxn['ID'].astype(str))]

# 将缺失的rxn添加到14067_rxn_1.xlsx中
if not missing_rxns.empty:
    # 将没有匹配到的rxn的相关信息添加到14067_rxn_1文件
    df_rxn_updated = pd.concat([df_rxn, missing_rxns[['id', 'locus_tag', 'name', 'equation', 'definition']].rename(columns={
        'id': 'ID', 
        'locus_tag': 'Genes', 
        'name': 'Name', 
        'equation': 'Equation', 
        'definition': 'Definition'
    })], ignore_index=True)

    # 输出为新的14067_rxn_2.xlsx文件
    df_rxn_updated.to_excel('14067_rxn_2.xlsx', index=False)

    print("Missing rxn data added and saved as 14067_rxn_2.xlsx.")
else:
    print("No missing rxn data to add.")
# Out:
# Missing rxn data added and saved as 14067_rxn_2.xlsx.
